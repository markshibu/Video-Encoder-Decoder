# %%
import numpy as np
import cv2
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_name = 'baboon.jpg'
rgb = cv2.imread(img_name,1)
#src = src[1:2,1:3]
#print(src[20][25])

# %%
blue,green,red = cv2.split(rgb)
gray = cv2.cvtColor(rgb , cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(15,5))
plt.subplot(151)
plt.title('rgb')
plt.imshow(rgb)
plt.subplot(152)
plt.title('red')
plt.imshow(red)
plt.subplot(153)
plt.title('green')
plt.imshow(green)
plt.subplot(154)
plt.title('blue')
plt.imshow(blue)
plt.subplot(155)
plt.title('gray')
plt.imshow(gray)

# %%
'''
cv2.namedWindow('Original image', cv2.WINDOW_NORMAL)
cv2.imshow('Original image', src)

cv2.namedWindow('blue', cv2.WINDOW_NORMAL)
cv2.imshow('blue', blue)

cv2.namedWindow('green', cv2.WINDOW_NORMAL)
cv2.imshow('green', green)

cv2.namedWindow('red', cv2.WINDOW_NORMAL)
cv2.imshow('red', red)

cv2.namedWindow('grey', cv2.WINDOW_NORMAL)
cv2.imshow('grey', ycrcb_image)



HSV_image = cv2.cvtColor(src , cv2.COLOR_BGR2HSV) 
Hue,Saturation,Value = cv2.split(HSV_image)
cv2.namedWindow('Hue', cv2.WINDOW_NORMAL)
cv2.imshow('Hue', Hue)

cv2.namedWindow('Saturation', cv2.WINDOW_NORMAL)
cv2.imshow('Saturation', Saturation)

cv2.namedWindow('Value', cv2.WINDOW_NORMAL)
cv2.imshow('Value', Value)
print(HSV_image[20][25])

YCR_CB_image = cv2.cvtColor(src , cv2.COLOR_RGB2YCR_CB) 
Y,Cb,Cr = cv2.split(YCR_CB_image)
cv2.namedWindow('Y', cv2.WINDOW_NORMAL)
cv2.imshow('Y', Y)

cv2.namedWindow('Cb', cv2.WINDOW_NORMAL)
cv2.imshow('Cb', Cb)

cv2.namedWindow('Cr', cv2.WINDOW_NORMAL)
cv2.imshow('Cr', Cr)
print(YCR_CB_image[20][25])


cv2.waitKey(0)
cv2.destroyAllWindows()
'''
